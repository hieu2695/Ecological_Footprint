# %%
# Load some libraries
import pandas as pd
import json
from pandas import DataFrame
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# read excel file
df = pd.read_excel("../data/Data2016.xlsx", header = 2, sheet_name = "Country Graphs 2019 Ed (2016)")

# %%
df.head()
# Out:
#      #  Unnamed: 1              Country Data Quality    HDI Per Capita GDP  \
# 0  1.0         NaN          Afghanistan           3A  0.494        583.055
# 1  2.0         NaN              Albania           3A  0.782        4683.52
# 2  3.0         NaN              Algeria           2A  0.753        4827.72
# 3  4.0         NaN               Angola           3A  0.577        3533.86
# 4  5.0         NaN  Antigua and Barbuda           2B  0.778          13286
#
#                       Region Income Group  \
# 0   Middle East/Central Asia           LI
# 1              Non-EU Europe           UM
# 2                     Africa           UM
# 3                     Africa           LM
# 4  Central America/Caribbean           HI
#
#   Total Ecological Footprint [gha per capita]  \
# 0                                    0.726752
# 1                                     2.00781
# 2                                     2.40732
# 3                                     1.01455
# ...

# %%
df = df[['Country','Region','Income Group']] # subset by selecting columns

# %%
df.head()
# Out:
#                Country                     Region Income Group
# 0          Afghanistan   Middle East/Central Asia           LI
# 1              Albania              Non-EU Europe           UM
# 2              Algeria                     Africa           UM
# 3               Angola                     Africa           LM
# 4  Antigua and Barbuda  Central America/Caribbean           HI

# %%
# change invalid values to NaN
df['Region']=df['Region'].replace('-', np.nan)
df['Income Group']=df['Income Group'].replace([0,'-'], np.nan)

# %%
df1 = pd.read_csv("../data/data0.csv") # read csv files
df1.reset_index(drop=True,inplace=True)
df2 = pd.read_csv("../data/data1.csv")
df2.reset_index(drop=True,inplace=True)

# %%
df1.head()
# Out:
#    Year               Country Code Parameter  Cropland  Grazing  Forest  \
# 0  1975  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 1  1976  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 2  1977  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 3  1978  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 4  1979  United Arab Emirates   AE       GDP       NaN      NaN     NaN
#
#    Fishing  Builtup  Carbon          Total
# 0      NaN      NaN     NaN  102479.187500
# 1      NaN      NaN     NaN  102319.726562
# 2      NaN      NaN     NaN  107452.179688
# 3      NaN      NaN     NaN   92822.359375
# 4      NaN      NaN     NaN  100480.437500

# %%
df2.head()
# Out:
#    Year               Country Code    Earths    HDI  Population  BiocapPerCap  \
# 0  1990  United Arab Emirates   AE  6.237739  0.727   1860174.0      2.602391
# 1  1991  United Arab Emirates   AE  6.859624  0.738   1970026.0      2.472270
# 2  1992  United Arab Emirates   AE  6.348376  0.742   2086639.0      2.382417
# 3  1993  United Arab Emirates   AE  6.331413  0.748   2207405.0      2.255677
# 4  1994  United Arab Emirates   AE  6.670189  0.756   2328686.0      2.143710
#
#    BiocapTotGHA  EFConsPerCap  EFConsTotGHA       DeRe  Percentage
# 0  4.840890e+06     12.902908  2.400160e+07 -10.300517   -3.958097
# 1  4.870447e+06     13.852905  2.729064e+07 -11.380635   -4.603313
# 2  4.971246e+06     12.829025  2.676956e+07 -10.446608   -4.384879
# 3  4.979203e+06     12.545192  2.769238e+07 -10.289515   -4.561609
# 4  4.992035e+06     13.122528  3.055830e+07 -10.978818   -5.121411

# %%
# append region and income group to df1
# try, except to ignore missing data from World and continents
for i in range (0,len(df1)):
    try:
        df1.ix[i,'Region'] = df[df.Country == df1.ix[i,'Country']]['Region'].values
        df1.ix[i,'Income'] = df[df.Country == df1.ix[i,'Country']]['Income Group'].values
    except:
        pass

# %%
# do the same for df2
for i in range (0,len(df2)):
    try:
        df2.ix[i,'Region'] = df[df.Country == df2.ix[i,'Country']]['Region'].values
        df2.ix[i,'Income'] = df[df.Country == df2.ix[i,'Country']]['Income Group'].values
    except:
        pass

# %%
df1.head()
# Out:
#    Year               Country Code Parameter  Cropland  Grazing  Forest  \
# 0  1975  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 1  1976  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 2  1977  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 3  1978  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 4  1979  United Arab Emirates   AE       GDP       NaN      NaN     NaN
#
#    Fishing  Builtup  Carbon          Total                    Region Income
# 0      NaN      NaN     NaN  102479.187500  Middle East/Central Asia     HI
# 1      NaN      NaN     NaN  102319.726562  Middle East/Central Asia     HI
# 2      NaN      NaN     NaN  107452.179688  Middle East/Central Asia     HI
# 3      NaN      NaN     NaN   92822.359375  Middle East/Central Asia     HI
# 4      NaN      NaN     NaN  100480.437500  Middle East/Central Asia     HI

# %%
df2.head()
# Out:
#    Year               Country Code    Earths    HDI  Population  BiocapPerCap  \
# 0  1990  United Arab Emirates   AE  6.237739  0.727   1860174.0      2.602391
# 1  1991  United Arab Emirates   AE  6.859624  0.738   1970026.0      2.472270
# 2  1992  United Arab Emirates   AE  6.348376  0.742   2086639.0      2.382417
# 3  1993  United Arab Emirates   AE  6.331413  0.748   2207405.0      2.255677
# 4  1994  United Arab Emirates   AE  6.670189  0.756   2328686.0      2.143710
#
#    BiocapTotGHA  EFConsPerCap  EFConsTotGHA       DeRe  Percentage  \
# 0  4.840890e+06     12.902908  2.400160e+07 -10.300517   -3.958097
# 1  4.870447e+06     13.852905  2.729064e+07 -11.380635   -4.603313
# 2  4.971246e+06     12.829025  2.676956e+07 -10.446608   -4.384879
# 3  4.979203e+06     12.545192  2.769238e+07 -10.289515   -4.561609
# 4  4.992035e+06     13.122528  3.055830e+07 -10.978818   -5.121411
#
#                      Region Income
# 0  Middle East/Central Asia     HI
# ...

# %%
df1.to_csv(path_or_buf="../data/data2.csv", index = False)

# %%
df2.to_csv(path_or_buf="../data/data3.csv", index = False)
