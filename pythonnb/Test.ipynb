# %%
# Load some libraries
import pandas as pd
import json
from pandas import DataFrame
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/DeRedata.csv")

# %%
df[df["Country"]!="Singapore"]["Percentage"].min()
# Out:
# -26.14192275332679

# %%
df.describe()
# Out:
#               Year       Earths          HDI    Population  BiocapPerCap  \
# count  4208.000000  4208.000000  4208.000000  4.208000e+03   4208.000000
# mean   2003.811787     1.784310     0.648832  3.955231e+07      3.742171
# std       7.658459     1.406117     0.167928  1.418168e+08      8.526996
# min    1990.000000     0.233184     0.199000  6.967000e+04      0.030922
# 25%    1997.000000     0.736698     0.513000  3.225496e+06      0.767360
# 50%    2004.000000     1.300692     0.673000  8.969450e+06      1.520597
# 75%    2010.000000     2.526217     0.781250  2.644474e+07      3.129840
# max    2016.000000     9.882354     0.951000  1.434972e+09     97.818091
#
#        BiocapTotGHA  EFConsPerCap  EFConsTotGHA         DeRe   Percentage
# count  4.208000e+03   4208.000000  4.208000e+03  4208.000000  4208.000000
# mean   7.326237e+07      3.207784  1.068604e+08     0.534387    -2.502471
# std    2.141643e+08      2.519712  3.793496e+08     8.685874    13.741944
# min    4.729306e+04      0.408075  1.237726e+05   -15.949668  -250.798648
# 25%    4.711267e+06      1.353044  6.739562e+06    -1.740801    -1.502228
# 50%    1.585980e+07      2.345621  2.014709e+07    -0.556990    -0.584729
# 75%    5.283086e+07      4.514294  6.132712e+07     0.701519     0.251258
# max    1.832325e+09     17.723456  5.260000e+09    95.346924     0.976959

# %%
df.head()
# Out:
#    Year               Country Code    Earths    HDI  Population  BiocapPerCap  \
# 0  1990  United Arab Emirates   AE  6.237739  0.727   1860174.0      2.602391
# 1  1991  United Arab Emirates   AE  6.859624  0.738   1970026.0      2.472270
# 2  1992  United Arab Emirates   AE  6.348376  0.742   2086639.0      2.382417
# 3  1993  United Arab Emirates   AE  6.331413  0.748   2207405.0      2.255677
# 4  1994  United Arab Emirates   AE  6.670189  0.756   2328686.0      2.143710
#
#    BiocapTotGHA  EFConsPerCap  EFConsTotGHA       DeRe  Percentage  \
# 0  4.840890e+06     12.902908  2.400160e+07 -10.300517   -3.958097
# 1  4.870447e+06     13.852905  2.729064e+07 -11.380635   -4.603313
# 2  4.971246e+06     12.829025  2.676956e+07 -10.446608   -4.384879
# 3  4.979203e+06     12.545192  2.769238e+07 -10.289515   -4.561609
# 4  4.992035e+06     13.122528  3.055830e+07 -10.978818   -5.121411
#
#                      Region Income   id
# 0  Middle East/Central Asia     HI  ARE
# 1  Middle East/Central Asia     HI  ARE
# 2  Middle East/Central Asia     HI  ARE
# 3  Middle East/Central Asia     HI  ARE
# 4  Middle East/Central Asia     HI  ARE

# %%
country_list = list(set(df.Country))

# %%
years = []
for i in range(1990,2017):
    years.append(i)

# %%
for country in country_list:
    if (df[df.Country == country]["Year"].tolist() != years):
        df = df[df.Country != country]

# %%
df.to_csv(path_or_buf="../data/GapMinder.csv", index = False)
