# %% [markdown]
# ### In this notebook, we create data for line charts.

# %%
# Load some libraries
import pandas as pd
import json
from pandas import DataFrame
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/data0.csv") # read csv files

# %%
df.head()
# Out:
#    Year               Country Code Parameter  Cropland  Grazing  Forest  \
# 0  1975  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 1  1976  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 2  1977  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 3  1978  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 4  1979  United Arab Emirates   AE       GDP       NaN      NaN     NaN
#
#    Fishing  Builtup  Carbon          Total
# 0      NaN      NaN     NaN  102479.187500
# 1      NaN      NaN     NaN  102319.726562
# 2      NaN      NaN     NaN  107452.179688
# 3      NaN      NaN     NaN   92822.359375
# 4      NaN      NaN     NaN  100480.437500

# %%
regions = ['Africa',
 'Asia',
 'Caribbean',
 'Central America',
 'Central Asia',
 'Eastern Africa',
 'Eastern Asia',
 'Eastern Europe',
 'Europe',
 'Latin America and the Caribbean',
 'Middle Africa',
 'North America',
 'Northern Africa',
 'Northern Europe',
 'Oceania',
 'South America',
 'South-Eastern Asia',
 'Southern Africa',
 'Southern Asia',
 'Southern Europe',
 'Western Africa',
 'Western Asia',
 'Western Europe',
 'World']

# %%
df1 = df[(df["Country"].isin(regions)) & (df["Parameter"].isin(["BiocapPerCap","EFConsPerCap"]))]
df1.drop(['Code', 'Cropland','Grazing','Forest','Fishing','Builtup','Carbon'], axis=1, inplace=True)
df1 = df1.sort_values(by=['Country','Year'], ascending = [True,True])

# %%
df1.head()
# Out:
#        Year Country     Parameter     Total
# 66087  1961  Africa  BiocapPerCap  4.028043
# 66147  1961  Africa  EFConsPerCap  1.339193
# 66286  1962  Africa  BiocapPerCap  3.963961
# 66346  1962  Africa  EFConsPerCap  1.359748
# 66485  1963  Africa  BiocapPerCap  3.879947

# %%
df1.to_csv(path_or_buf="../data/LineChart.csv", index = False)
