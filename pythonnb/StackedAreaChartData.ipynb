# %% [markdown]
# ### This notebook preprocesses data for stacked area charts

# %%
# Load some libraries
import pandas as pd
import json
from pandas import DataFrame
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/data0.csv") # read csv files

# %%
df.head()
# Out:
#    Year               Country Code Parameter  Cropland  Grazing  Forest  \
# 0  1975  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 1  1976  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 2  1977  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 3  1978  United Arab Emirates   AE       GDP       NaN      NaN     NaN
# 4  1979  United Arab Emirates   AE       GDP       NaN      NaN     NaN
#
#    Fishing  Builtup  Carbon          Total
# 0      NaN      NaN     NaN  102479.187500
# 1      NaN      NaN     NaN  102319.726562
# 2      NaN      NaN     NaN  107452.179688
# 3      NaN      NaN     NaN   92822.359375
# 4      NaN      NaN     NaN  100480.437500

# %%
# drop unused columns
df.drop(['Code', 'Total'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Year               Country Parameter  Cropland  Grazing  Forest  Fishing  \
# 0  1975  United Arab Emirates       GDP       NaN      NaN     NaN      NaN
# 1  1976  United Arab Emirates       GDP       NaN      NaN     NaN      NaN
# 2  1977  United Arab Emirates       GDP       NaN      NaN     NaN      NaN
# 3  1978  United Arab Emirates       GDP       NaN      NaN     NaN      NaN
# 4  1979  United Arab Emirates       GDP       NaN      NaN     NaN      NaN
#
#    Builtup  Carbon
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN

# %%
regions = ['Africa',
 'Asia',
 'Caribbean',
 'Central America',
 'Central Asia',
 'Eastern Africa',
 'Eastern Asia',
 'Eastern Europe',
 'Europe',
 'Latin America and the Caribbean',
 'Middle Africa',
 'North America',
 'Northern Africa',
 'Northern Europe',
 'Oceania',
 'South America',
 'South-Eastern Asia',
 'Southern Africa',
 'Southern Asia',
 'Southern Europe',
 'Western Africa',
 'Western Asia',
 'Western Europe',
 'World']

# %% [markdown]
# ### 1. Ecological Footprint as Number of Earths

# %%
df1 = df[df.Parameter == "Earths"]
df1.drop(['Parameter'], axis=1, inplace=True)

# %%
# due to large number of countries
# we filter the data of specific regions and the global data
df2 = df1.loc[df['Country'].isin(regions)] 
df2 = df2.fillna(0) # fill NaN value as 0
# sort the dataframe
df2 = df2.sort_values(by=['Country','Year'], ascending = [False,True])

# %%
df2.head()
# Out:
#        Year Country  Cropland   Grazing    Forest   Fishing   Builtup  \
# 66212  1961   World  0.150054  0.084768  0.137532  0.030539  0.008501
# 66411  1962   World  0.155637  0.085009  0.137814  0.031741  0.008955
# 66610  1963   World  0.157349  0.086674  0.139167  0.032749  0.009167
# 66809  1964   World  0.161658  0.085610  0.143449  0.031934  0.009580
# 67008  1965   World  0.163904  0.087516  0.144819  0.034261  0.009868
#
#          Carbon
# 66212  0.320909
# 66411  0.332771
# 66610  0.356304
# 66809  0.377762
# 67008  0.397384

# %%
df2.to_csv(path_or_buf="../data/StackAreaChart_Earths.csv", index = False)

# %% [markdown]
# ### 2. Biocapacity Per Capita

# %%
df3 = df[df.Parameter == "BiocapPerCap"]
df3.drop(['Parameter'], axis=1, inplace=True)

# %%
df3.head()
# Out:
#     Year               Country  Cropland   Grazing    Forest   Fishing  \
# 5   1980  United Arab Emirates  0.035951  0.007318  0.447696  4.189307
# 12  1981  United Arab Emirates  0.040069  0.006819  0.416497  3.903319
# 19  1982  United Arab Emirates  0.055132  0.006390  0.392868  3.658069
# 26  1983  United Arab Emirates  0.057204  0.006051  0.373031  3.464010
# 33  1984  United Arab Emirates  0.049506  0.005714  0.354303  3.270834
#
#     Builtup  Carbon
# 5       0.0     0.0
# 12      0.0     0.0
# 19      0.0     0.0
# 26      0.0     0.0
# 33      0.0     0.0

# %%
df4 = df3.loc[df['Country'].isin(regions)] 
df4 = df4.fillna(0)
# sort the dataframe
df4 = df4.sort_values(by=['Country','Year'], ascending = [False,True])

# %%
df4.head()
# Out:
#        Year Country  Cropland   Grazing    Forest   Fishing   Builtup  Carbon
# 66065  1961   World  0.467549  0.478144  1.778773  0.364910  0.026488     0.0
# 66264  1962   World  0.478817  0.469073  1.743816  0.357243  0.027549     0.0
# 66463  1963   World  0.474732  0.458938  1.706461  0.349266  0.027658     0.0
# 66662  1964   World  0.480774  0.449920  1.673070  0.341765  0.028490     0.0
# 66861  1965   World  0.478975  0.440820  1.639838  0.333822  0.028836     0.0

# %%
df4.to_csv(path_or_buf="../data/StackAreaChart_Biocap.csv", index = False)
